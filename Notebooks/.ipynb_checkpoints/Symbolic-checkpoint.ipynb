# %% [markdown]
# # Symbolic analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %%
init_printing()

# %%
x, y, x1, y1, x2, y2, xp, yp, xm, ym, ϵ1, ϵ2, k, a, b, c, s = symbols('x, y, x_1, y_1, x_2, y_2, x_+, y_+, x_-, y_-, ϵ_1, ϵ_2, k, a, b, c, s')

# %%
f = (x - x**3/3 - c*y - a)/(ϵ1*ϵ2)
g = (x - c*y)/ϵ1
z = (f,g)
z
# Out:
# ⎛            3              ⎞
# ⎜           x               ⎟
# ⎜-a - c⋅y - ── + x          ⎟
# ⎜           3       -c⋅y + x⎟
# ⎜─────────────────, ────────⎟
# ⎝      ϵ₁⋅ϵ₂           ϵ₁   ⎠

# %%
solve(z,(x,y))
# Out:
# ⎡                              ⎛                             3 ___ 3 ____    5
# ⎢                              ⎜                             ╲╱ 3 ⋅╲╱ -a    3
# ⎢⎛              3 ___ 3 ____⎞  ⎜3 ____ ⎛  3 ___    5/6  ⎞  - ──────────── + ──
# ⎢⎜3 ___ 3 ____  ╲╱ 3 ⋅╲╱ -a ⎟  ⎜╲╱ -a ⋅⎝- ╲╱ 3  + 3   ⋅ⅈ⎠         2
# ⎢⎜╲╱ 3 ⋅╲╱ -a , ────────────⎟, ⎜─────────────────────────, ───────────────────
# ⎣⎝                   c      ⎠  ⎝            2                            c
#
# /6   3 ____⎞  ⎛                             3 ___ 3 ____    5/6   3 ____⎞⎤
#   ⋅ⅈ⋅╲╱ -a ⎟  ⎜                             ╲╱ 3 ⋅╲╱ -a    3   ⋅ⅈ⋅╲╱ -a ⎟⎥
# ───────────⎟  ⎜ 3 ____ ⎛3 ___    5/6  ⎞   - ──────────── - ─────────────⎟⎥
#     2      ⎟  ⎜-╲╱ -a ⋅⎝╲╱ 3  + 3   ⋅ⅈ⎠          2               2      ⎟⎥
# ───────────⎟, ⎜─────────────────────────, ──────────────────────────────⎟⎥
#            ⎠  ⎝            2                            c               ⎠⎦

# %%
f1 = f.subs([(x, x1), (y,y1)]) + k*(x2-x1)
f2 = f.subs([(x, x2), (y,y2)]) + k*(x1-x2)
g1 = g.subs([(x, x1), (y,y1)])
g2 = g.subs([(x, x2), (y,y2)])

(f1, g1, f2, g2)
# Out:
# ⎛                             3
# ⎜                           x₁                                              x₂
# ⎜               -a - c⋅y₁ - ─── + x₁                            -a - c⋅y₂ - ──
# ⎜                            3        -c⋅y₁ + x₁                             3
# ⎜k⋅(-x₁ + x₂) + ────────────────────, ──────────, k⋅(x₁ - x₂) + ──────────────
# ⎝                      ϵ₁⋅ϵ₂              ϵ₁                           ϵ₁⋅ϵ₂
#
# 3                 ⎞
#                   ⎟
# ─ + x₂            ⎟
#         -c⋅y₂ + x₂⎟
# ──────, ──────────⎟
#             ϵ₁    ⎠

# %%
zp = simplify((f1+f2, g1+g2))
zm = simplify((f1-f2, g1-g2))
(zp, zm)
# Out:
# ⎛⎛                       3          3                             ⎞  ⎛
# ⎜⎜                     x₁         x₂                              ⎟  ⎜
# ⎜⎜-2⋅a - c⋅y₁ - c⋅y₂ - ─── + x₁ - ─── + x₂                        ⎟  ⎜-c⋅y₁ +
# ⎜⎜                      3          3        -c⋅y₁ - c⋅y₂ + x₁ + x₂⎟  ⎜
# ⎜⎜────────────────────────────────────────, ──────────────────────⎟, ⎜────────
# ⎝⎝                 ϵ₁⋅ϵ₂                              ϵ₁          ⎠  ⎝
#
#                                3          3                             ⎞⎞
#                              x₁         x₂                              ⎟⎟
# c⋅y₂ - 2⋅k⋅ϵ₁⋅ϵ₂⋅(x₁ - x₂) - ─── + x₁ + ─── - x₂                        ⎟⎟
#                               3          3        -c⋅y₁ + c⋅y₂ + x₁ - x₂⎟⎟
# ────────────────────────────────────────────────, ──────────────────────⎟⎟
#                  ϵ₁⋅ϵ₂                                      ϵ₁          ⎠⎠

# %%
zzp = (simplify(zp[0].subs([(x1,(xp+xm)/2), (x2,(xp-xm)/2), (y1,(yp+ym)/2), (y2,(yp-ym)/2)])),
     simplify(zp[1].subs([(x1,(xp+xm)/2), (x2,(xp-xm)/2), (y1,(yp+ym)/2), (y2,(yp-ym)/2)])))
zzm = (simplify(zm[0].subs([(x1,(xp+xm)/2), (x2,(xp-xm)/2), (y1,(yp+ym)/2), (y2,(yp-ym)/2)])),
     simplify(zm[1].subs([(x1,(xp+xm)/2), (x2,(xp-xm)/2), (y1,(yp+ym)/2), (y2,(yp-ym)/2)])))

# %%
zz = (zzp, zzm)

# %%
M = Matrix([
    [diff(zzp[0],xp), diff(zzp[1],xp), diff(zzm[0],xp), diff(zzm[1],xp)],
    [diff(zzp[0],yp), diff(zzp[1],yp), diff(zzm[0],yp), diff(zzm[1],yp)],
    [diff(zzp[0],xm), diff(zzp[1],xm), diff(zzm[0],xm), diff(zzm[1],xm)],
    [diff(zzp[0],ym), diff(zzp[1],ym), diff(zzm[0],ym), diff(zzm[1],ym)],
    
])

# %%
M
# Out:
# ⎡    2     2                                          ⎤
# ⎢  x₊    x₋                                           ⎥
# ⎢- ─── - ─── + 1                                      ⎥
# ⎢   4     4       1             -x₊⋅x₋                ⎥
# ⎢───────────────  ──            ───────             0 ⎥
# ⎢     ϵ₁⋅ϵ₂       ϵ₁            2⋅ϵ₁⋅ϵ₂               ⎥
# ⎢                                                     ⎥
# ⎢      -c         -c                                  ⎥
# ⎢     ─────       ───              0                0 ⎥
# ⎢     ϵ₁⋅ϵ₂        ϵ₁                                 ⎥
# ⎢                                                     ⎥
# ⎢                                     2     2         ⎥
# ⎢                                   x₊    x₋          ⎥
# ⎢                      -2⋅k⋅ϵ₁⋅ϵ₂ - ─── - ─── + 1     ⎥
# ⎢    -x₊⋅x₋                          4     4       1  ⎥
# ⎢    ───────       0   ──────────────────────────  ── ⎥
# ⎢    2⋅ϵ₁⋅ϵ₂                     ϵ₁⋅ϵ₂             ϵ₁ ⎥
# ⎢                                                     ⎥
# ⎢                                 -c               -c ⎥
# ⎢       0          0             ─────             ───⎥
# ⎣                                ϵ₁⋅ϵ₂              ϵ₁⎦

# %%
zz
# Out:
# ⎛⎛                3        2                 ⎞  ⎛                         2
# ⎜⎜              x₊    x₊⋅x₋                  ⎟  ⎜                       x₊ ⋅x₋
# ⎜⎜-2⋅a - c⋅y₊ - ─── - ────── + x₊            ⎟  ⎜-c⋅y₋ - 2⋅k⋅x₋⋅ϵ₁⋅ϵ₂ - ──────
# ⎜⎜               12     4          -c⋅y₊ + x₊⎟  ⎜                         4
# ⎜⎜───────────────────────────────, ──────────⎟, ⎜─────────────────────────────
# ⎝⎝             ϵ₁⋅ϵ₂                   ϵ₁    ⎠  ⎝                 ϵ₁⋅ϵ₂
#
#      3                 ⎞⎞
#    x₋                  ⎟⎟
#  - ─── + x₋            ⎟⎟
#     12       -c⋅y₋ + x₋⎟⎟
# ───────────, ──────────⎟⎟
#                  ϵ₁    ⎠⎠

# %%
ss = solve(z,(x,y))

# %%
zz
# Out:
# ⎛⎛                3        2                 ⎞  ⎛                         2
# ⎜⎜              x₊    x₊⋅x₋                  ⎟  ⎜                       x₊ ⋅x₋
# ⎜⎜-2⋅a - c⋅y₊ - ─── - ────── + x₊            ⎟  ⎜-c⋅y₋ - 2⋅k⋅x₋⋅ϵ₁⋅ϵ₂ - ──────
# ⎜⎜               12     4          -c⋅y₊ + x₊⎟  ⎜                         4
# ⎜⎜───────────────────────────────, ──────────⎟, ⎜─────────────────────────────
# ⎝⎝             ϵ₁⋅ϵ₂                   ϵ₁    ⎠  ⎝                 ϵ₁⋅ϵ₂
#
#      3                 ⎞⎞
#    x₋                  ⎟⎟
#  - ─── + x₋            ⎟⎟
#     12       -c⋅y₋ + x₋⎟⎟
# ───────────, ──────────⎟⎟
#                  ϵ₁    ⎠⎠

# %%
zz_flat = (zz[0][0], zz[0][1], zz[1][0], zz[1][1])

# %%
solve(zz_flat, (xp,yp,xm,ym))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-592ed0531528> in <module>
# ----> 1 solve(zz_flat, (xp,yp,xm,ym))
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1162         solution = _solve(f[0], *symbols, **flags)
#    1163     else:
# -> 1164         solution = _solve_system(f, symbols, **flags)
#    1165
#    1166     #
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1843             else:
#    1844                 try:
# -> 1845                     result = solve_poly_system(polys, *symbols)
#    1846                     if result:
#    1847                         solved_syms = symbols
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/polysys.py in solve_poly_system(seq, *gens, **args)
#      45                 pass
#      46
# ---> 47     return solve_generic(polys, opt)
#      48
#      49
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/polysys.py in solve_generic(polys, opt)
#     235
#     236     try:
# --> 237         result = _solve_reduced_system(polys, opt.gens, entry=True)
#     238     except CoercionFailed:
#     239         raise NotImplementedError
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/polysys.py in _solve_reduced_system(system, gens, entry)
#     224                     new_system.append(eq)
#     225
# --> 226             for solution in _solve_reduced_system(new_system, new_gens):
#     227                 solutions.append(solution + (zero,))
#     228
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/polysys.py in _solve_reduced_system(system, gens, entry)
#     183             return [ (zero,) for zero in zeros ]
#     184
# --> 185         basis = groebner(system, gens, polys=True)
#     186
#     187         if len(basis) == 1 and basis[0].is_ground:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in groebner(F, *gens, **args)
#    6745
#    6746     """
# -> 6747     return GroebnerBasis(F, *gens, **args)
#    6748
#    6749
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in __new__(cls, F, *gens, **args)
#    6784         polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
#    6785
# -> 6786         G = _groebner(polys, ring, method=opt.method)
#    6787         G = [Poly._from_dict(g, opt) for g in G]
#    6788
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/groebnertools.py in groebner(seq, ring, method)
#      43             seq = [ s.set_ring(ring) for s in seq ]
#      44
# ---> 45     G = _groebner(seq, ring)
#      46
#      47     if orig is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/groebnertools.py in _buchberger(f, ring)
#     236         # ordering divisors is on average more efficient [Cox] page 111
#     237         G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 238         ht = normal(h, G1)
#     239
#     240         if ht:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/groebnertools.py in normal(g, J)
#     102
#     103     def normal(g, J):
# --> 104         h = g.rem([ f[j] for j in J ])
#     105
#     106         if not h:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/rings.py in rem(self, G)
#    1486                     for mg, cg in g.iterterms():
#    1487                         m1 = monomial_mul(mg, m)
# -> 1488                         c1 = get(m1, zero) - c*cg
#    1489                         if not c1:
#    1490                             del f[m1]
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in __mul__(f, g)
#      87
#      88             if g is not None:
# ---> 89                 return f.simplify(f.ex*g.ex)
#      90             else:
#      91                 return NotImplemented
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in simplify(f, ex)
#      47
#      48         def simplify(f, ex):
# ---> 49             return f.__class__(ex.cancel())
#      50
#      51         def __abs__(f):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/expr.py in cancel(self, *gens, **args)
#    3243         """See the cancel function in sympy.polys"""
#    3244         from sympy.polys import cancel
# -> 3245         return cancel(self, *gens, **args)
#    3246
#    3247     def invert(self, g, *gens, **args):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6623             return f.xreplace(dict(reps))
#    6624
# -> 6625     c, P, Q = F.cancel(G)
#    6626
#    6627     if not isinstance(f, (tuple, Tuple)):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, g, include)
#    3691
#    3692         if hasattr(F, 'cancel'):
# -> 3693             result = F.cancel(G, include=include)
#    3694         else:  # pragma: no cover
#    3695             raise OperationNotSupported(f, 'cancel')
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/polyclasses.py in cancel(f, g, include)
#     696             F, G = dmp_cancel(F, G, lev, dom, include=True)
#     697         else:
# --> 698             cF, cG, F, G = dmp_cancel(F, G, lev, dom, include=False)
#     699
#     700         F, G = per(F), per(G)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_cancel(f, g, u, K, include)
#    1872         cp, cq = K.one, K.one
#    1873
# -> 1874     _, p, q = dmp_inner_gcd(f, g, u, K)
#    1875
#    1876     if K0 is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     958             G = dmp_content(g, u, K)
#     959         else:
# --> 960             F = dmp_content(f, u, K)
#     961             G = dmp_LC(g, K)
#     962
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1339
#    1340         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1341             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1342
#    1343             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1314     """
#    1315     if not u:
# -> 1316         return dup_zz_heu_gcd(f, g, K)
#    1317
#    1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in dup_zz_heu_gcd(f, g, K)
#    1217             cfg = gg // h
#    1218
# -> 1219             h = _dup_zz_gcd_interpolate(h, x, K)
#    1220             h = dup_primitive(h, K)[1]
#    1221
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/polys/euclidtools.py in _dup_zz_gcd_interpolate(h, x, K)
#    1139
#    1140     while h:
# -> 1141         g = h % x
#    1142
#    1143         if g > x // 2:
#
# KeyboardInterrupt:
